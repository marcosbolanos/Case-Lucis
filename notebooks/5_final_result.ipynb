# %%
import os
import sys

# Get the current working directory (where the notebook is running)
cwd = os.getcwd()

# Add the backend directory to sys.path
sys.path.append(os.path.join(cwd, '../src'))
os.chdir("../")

from src.ai_doctor_agent import ask_ai_doctor_agent

# %%
question="""
Hi, could you give me a basic summary of my test results ?
"""

res = await ask_ai_doctor_agent(question)

print(res)
# Out:
# I'll provide a summary of your blood test results from May 2024 to April 2025. Let me analyze the key findings and trends.
#
# ## Basic Summary of Your Blood Test Results
#
# Looking at your results, I notice several important areas to highlight:
#
# ### Areas of Concern
#
# 1. **Lipoprotein(a)** is significantly elevated in both tests:
#    - May 2024: 333 mg/L (MEDICAL_CRITICAL)
#    - April 2025: 750 mg/L (MEDICAL_CRITICAL) - showing a concerning increase
#
# 2. **HDL Cholesterol** has decreased:
#    - May 2024: 80 mg/dL (LONGEVITY_GOOD)
#    - April 2025: 38 mg/dL (MEDICAL_BORDERLINE) - significant drop
#
# 3. **Vitamin D** remains low:
#    - May 2024: 46 ng/mL (MEDICAL_BORDERLINE)
#    - April 2025: 23 ng/mL (MEDICAL_BORDERLINE) - showing further decline
#
# Let me search for evidence-based information about these key concerns, particularly the elevated Lipoprotein(a) which appears to be your most critical issue.
# ✅ Successfully parsed 15 articles from PubMed
# ...

# %%
question="""
Hi, what are the main things I could do to improve my health ? What should I focus on in priority ?
"""

res = await ask_ai_doctor_agent(question)

print(res)
# Out:
# I'll analyze your blood test results to identify the key areas for health improvement. Let me first identify the concerning biomarkers that need attention.
#
# Looking at your April 2025 results (most recent), I notice several areas that could be improved:
#
# 1. **Lipoprotein(a)** is critically high at 750 mg/L (marked as MEDICAL_CRITICAL)
# 2. **HDL cholesterol** is low at 38 mg/dL (marked as MEDICAL_BORDERLINE)
# 3. **Vitamin D** is low at 23 ng/mL (marked as MEDICAL_BORDERLINE)
#
# Let me search for evidence-based interventions for these specific issues to provide you with actionable recommendations.
# ✅ Successfully parsed 15 articles from PubMed
# ✅ Successfully parsed 15 articles from PubMed
# ✅ Successfully parsed 15 articles from PubMed
# # Comprehensive Health Improvement Plan Based on Your Blood Test Results
#
# ...

# %%
question="""
Hi, I noticed that my biological age increased. What are the best evidence-based strategies to keep it as low as possible ?
"""

res = await ask_ai_doctor_agent(question)

print(res)
# Out:
# I'll help you understand biological age and evidence-based strategies to keep it low. First, I should clarify that I don't see your biological age increasing in the data provided - in fact, I only see one measurement from May 2024 showing your biological age at 23.05 years (which is excellent since your chronological age is 32).
#
# To provide you with evidence-based strategies for maintaining a low biological age, I'll need to search for the latest research on this topic.
# ✅ Successfully parsed 15 articles from PubMed
# ⚠️ PubMed API error response: <?xml version="1.0" ?>
# <!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2025//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_250101.dtd">
# <PubmedArticleSet>
# <PubmedArticl...
# ✅ Successfully parsed 15 articles from PubMed
# ✅ Successfully parsed 15 articles from PubMed
# # Evidence-Based Strategies to Maintain a Low Biological Age
#
# ...
